# %% [markdown]
# # Pliki CSV

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Zadanie 1
#
# W pliku `LaqnData_02.csv` znajdują się dane na temat jakości powietrza z punktu _Bexley - Slade Green_  w Londynie. Dane zostały pobrane ze strony projektu London Air (https://www.londonair.org.uk).
#
# Plik zawiera dane n.t.:
#
# - Prędkości wiatru (WSPD)
# - Kierunku wiatru (WDIR)
# - Stężenia tlenku węgla (CO)
# - Stężenia pyłu PM2.5 (FINE)
# - Stężenia pyłu PM10 (PM10)
#
# ### Wykonaj następujące ćwieczenia
#
# 1. Wczytaj zawartość pliku CSV do DataFrame.
# 2. Przekonwertuj kolumnę z datą pomiaru na odpowiedni format.
# 3. Zmień Indeksowanie DataFrame na kolumnę z datą.
# 4. Usuń te cechy dla których nie istnieją żadne dane.
# 5. Zmień strukturę DataFrame tak, aby dane n.t. wszystkich odnotowanych cech dla danej daty znajdowały się w jednym wierszu.
#     (aktualnie każda cecha jest przechowywana osobno - patrz kolumna `Species`)
# 6. Uzupełnij brakujące wartości cech wartością 0 (zero)
# 7. Uzupełnij brakujące wartości cech ich średnią z danego dnia.

# %%
df = pd.read_csv('LaqnData_02.csv',index_col=2, parse_dates=[2])
df = df.dropna(subset="Value")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-d524be06d7b9> in <module>()
#       1 df = pd.read_csv('LaqnData_02.csv',index_col=2, parse_dates=[2])
# ----> 2 df = df.dropna(subset="Value")
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in dropna(self, axis, how, thresh, subset, inplace)
#    4280             if subset is not None:
#    4281                 ax = self._get_axis(agg_axis)
# -> 4282                 indices = ax.get_indexer_for(subset)
#    4283                 check = indices == -1
#    4284                 if check.any():
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_indexer_for(self, target, **kwargs)
#    3383         """
#    3384         if self.is_unique:
# -> 3385             return self.get_indexer(target, **kwargs)
#    3386         indexer, _ = self.get_indexer_non_unique(target, **kwargs)
#    3387         return indexer
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_indexer(self, target, method, limit, tolerance)
#    3220     def get_indexer(self, target, method=None, limit=None, tolerance=None):
#    3221         method = missing.clean_reindex_fill_method(method)
# -> 3222         target = _ensure_index(target)
#    3223         if tolerance is not None:
#    3224             tolerance = self._convert_tolerance(tolerance, target)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in _ensure_index(index_like, copy)
#    4972             index_like = copy(index_like)
#    4973
# -> 4974     return Index(index_like)
#    4975
#    4976
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in __new__(cls, data, dtype, copy, name, fastpath, tupleize_cols, **kwargs)
#     435                          **kwargs)
#     436         elif data is None or is_scalar(data):
# --> 437             cls._scalar_data_error(data)
#     438         else:
#     439             if tupleize_cols and is_list_like(data):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in _scalar_data_error(cls, data)
#     895         raise TypeError('{0}(...) must be called with a collection of some '
#     896                         'kind, {1} was passed'.format(cls.__name__,
# --> 897                                                       repr(data)))
#     898
#     899     @classmethod
#
# TypeError: Index(...) must be called with a collection of some kind, 'Value' was passed

# %%
df.fillna(0)
# Out:
#                     Site Species  Value   Units Provisional or Ratified
# ReadingDateTime
# 2005-01-01 00:00:00  BX1      CO    0.8  mg m-3                       R
# 2005-01-01 00:15:00  BX1      CO    0.6  mg m-3                       R
# 2005-01-01 00:30:00  BX1      CO    0.6  mg m-3                       R
# 2005-01-01 01:15:00  BX1      CO    0.7  mg m-3                       R
# 2005-01-01 01:30:00  BX1      CO    1.3  mg m-3                       R
# 2005-01-01 01:45:00  BX1      CO    0.5  mg m-3                       R
# 2005-01-01 02:00:00  BX1      CO    0.3  mg m-3                       R
# 2005-01-01 02:15:00  BX1      CO    0.3  mg m-3                       R
# 2005-01-01 02:30:00  BX1      CO    0.3  mg m-3                       R
# 2005-01-01 02:45:00  BX1      CO    0.3  mg m-3                       R
# 2005-01-01 03:00:00  BX1      CO    0.3  mg m-3                       R
# 2005-01-01 03:15:00  BX1      CO    0.2  mg m-3                       R
# 2005-01-01 03:30:00  BX1      CO    0.2  mg m-3                       R
# 2005-01-01 03:45:00  BX1      CO    0.2  mg m-3                       R
# 2005-01-01 04:00:00  BX1      CO    0.2  mg m-3                       R
# 2005-01-01 04:15:00  BX1      CO    0.2  mg m-3                       R
# 2005-01-01 04:30:00  BX1      CO    0.2  mg m-3                       R
# 2005-01-01 04:45:00  BX1      CO    0.2  mg m-3                       R
# 2005-01-01 05:00:00  BX1      CO    0.2  mg m-3                       R
# 2005-01-01 05:15:00  BX1      CO    0.2  mg m-3                       R
# 2005-01-01 05:30:00  BX1      CO    0.2  mg m-3                       R
# 2005-01-01 05:45:00  BX1      CO    0.2  mg m-3                       R
# 2005-01-01 06:00:00  BX1      CO    0.2  mg m-3                       R
# 2005-01-01 06:15:00  BX1      CO    0.2  mg m-3                       R
# 2005-01-01 06:30:00  BX1      CO    0.3  mg m-3                       R
# 2005-01-01 06:45:00  BX1      CO    0.3  mg m-3                       R
# 2005-01-01 07:00:00  BX1      CO    0.2  mg m-3                       R
# 2005-01-01 07:15:00  BX1      CO    0.2  mg m-3                       R
# 2005-01-01 07:30:00  BX1      CO    0.2  mg m-3                       R
# 2005-01-01 07:45:00  BX1      CO    0.2  mg m-3                       R
# ...                  ...     ...    ...     ...                     ...
# 2005-12-31 16:30:00  BX1    WSPD    2.4     m/s                       P
# 2005-12-31 16:45:00  BX1    WSPD    2.4     m/s                       P
# 2005-12-31 17:00:00  BX1    WSPD    2.0     m/s                       P
# 2005-12-31 17:15:00  BX1    WSPD    1.9     m/s                       P
# 2005-12-31 17:30:00  BX1    WSPD    2.0     m/s                       P
# 2005-12-31 17:45:00  BX1    WSPD    1.9     m/s                       P
# 2005-12-31 18:00:00  BX1    WSPD    2.7     m/s                       P
# 2005-12-31 18:15:00  BX1    WSPD    2.2     m/s                       P
# 2005-12-31 18:30:00  BX1    WSPD    2.1     m/s                       P
# 2005-12-31 18:45:00  BX1    WSPD    2.2     m/s                       P
# 2005-12-31 19:00:00  BX1    WSPD    2.1     m/s                       P
# 2005-12-31 19:15:00  BX1    WSPD    2.1     m/s                       P
# 2005-12-31 19:30:00  BX1    WSPD    1.9     m/s                       P
# 2005-12-31 19:45:00  BX1    WSPD    1.9     m/s                       P
# 2005-12-31 20:00:00  BX1    WSPD    2.1     m/s                       P
# 2005-12-31 20:15:00  BX1    WSPD    2.0     m/s                       P
# 2005-12-31 20:30:00  BX1    WSPD    2.3     m/s                       P
# 2005-12-31 20:45:00  BX1    WSPD    1.8     m/s                       P
# 2005-12-31 21:00:00  BX1    WSPD    1.8     m/s                       P
# 2005-12-31 21:15:00  BX1    WSPD    1.6     m/s                       P
# 2005-12-31 21:30:00  BX1    WSPD    1.5     m/s                       P
# 2005-12-31 21:45:00  BX1    WSPD    1.4     m/s                       P
# 2005-12-31 22:00:00  BX1    WSPD    1.7     m/s                       P
# 2005-12-31 22:15:00  BX1    WSPD    2.0     m/s                       P
# 2005-12-31 22:30:00  BX1    WSPD    2.0     m/s                       P
# 2005-12-31 22:45:00  BX1    WSPD    2.4     m/s                       P
# 2005-12-31 23:00:00  BX1    WSPD    2.3     m/s                       P
# 2005-12-31 23:15:00  BX1    WSPD    2.2     m/s                       P
# 2005-12-31 23:30:00  BX1    WSPD    2.1     m/s                       P
# 2005-12-31 23:45:00  BX1    WSPD    2.1     m/s                       P
#
# [161411 rows x 5 columns]

# %%
print(df.index.dtype)
# Out:
# datetime64[ns]

# %% [markdown]
# ## Zadanie 2
#
# W pliku `movie_metadata.csv` znajdują się dane n.t. filmów amerykańskich.
#
# ### Wykonaj następujące ćwiczenia
#
# 1. Wczytaj zawartość pliku CSV do DataFrame.
# 2. Przekonwertuj kolumnę zawierającą rok produkcji na datę i stwórz na niej indeks.
# 3. Zamień wartości kolumny `Plot_keywords` na listę.
# 4. Zamień wartości kolumny `Genres` na osobne kolumny.

# %%
df2 = pd.read_csv('movie_metadata.csv', date_parser=[16])

# %%
print(df2.title_year.dtype)
# Out:
# float64
